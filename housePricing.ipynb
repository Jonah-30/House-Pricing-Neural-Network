# %% [markdown]
# Import packages and datasets.

# %%
import pandas as pd
import keras
import numpy as np
from google.colab import drive
drive.mount('/content/drive')

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/House Pricing AI/HousingPrices.csv')
dataset.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    YearBuilt  2ndFlrSF  GrLivArea  ...  TotRmsAbvGrd  YrSold  SalePrice
# 0       2003       854       1710  ...             8    2008     208500
# 1       1976         0       1262  ...             6    2007     181500
# 2       2001       866       1786  ...             6    2008     223500
# 3       1915       756       1717  ...             7    2006     140000
# 4       2000      1053       2198  ...             9    2008     250000
#
# [5 rows x 9 columns]

# %% [markdown]
# Seperate the inputs and outputs in the data.

# %%
x = dataset.drop(columns=["SalePrice"])
y = dataset["SalePrice"]

# %% [markdown]
# Initialize the nueral network.

# %%
model = keras.models.Sequential()

# %% [markdown]
# Structure the neural network and set the neurons.

# %%
model.add(keras.layers.Dense(8, activation='relu', input_shape=(8,)))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(1))

# %% [markdown]
# Set up the back-propagation.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# Train the neural network.

# %%
model.fit(x, y, epochs=30, callbacks=[keras.callbacks.EarlyStopping(patience=3)])
# Out:
# Epoch 1/30
# WARNING:tensorflow:Model was constructed with shape (None, 1460, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1460, 8), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 8).
# WARNING:tensorflow:Model was constructed with shape (None, 1460, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1460, 8), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 8).
# 46/46 [==============================] - 1s 977us/step - loss: 24135086167.1489
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 2/30
# 46/46 [==============================] - 0s 1ms/step - loss: 6361997312.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 3/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4448930865.0213
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 4/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4549248283.2340
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 5/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4547723035.2340
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 6/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4626759908.7660
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 7/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4347268956.5957
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 8/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4192321339.9149
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 9/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4423305662.6383
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 10/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4474116259.4043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 11/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4797523254.4681
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 12/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4170941410.0426
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 13/30
# 46/46 [==============================] - 0s 998us/step - loss: 4611754555.9149
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 14/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4380575874.7234
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 15/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4141273344.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 16/30
# 46/46 [==============================] - 0s 1ms/step - loss: 5341204294.8085
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 17/30
# 46/46 [==============================] - 0s 1ms/step - loss: 5077460283.9149
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 18/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4725918109.9574
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 19/30
# 46/46 [==============================] - 0s 1ms/step - loss: 5011609828.7660
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 20/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4424625440.6809
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 21/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4393067792.3404
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 22/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4248696396.2553
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 23/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4296897421.6170
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 24/30
# 46/46 [==============================] - 0s 1ms/step - loss: 3889836685.6170
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 25/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4110152769.3617
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 26/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4503526269.2766
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 27/30
# 46/46 [==============================] - 0s 978us/step - loss: 4692207332.7660
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 28/30
# 46/46 [==============================] - 0s 2ms/step - loss: 4013952648.1702
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 29/30
# 46/46 [==============================] - 0s 2ms/step - loss: 4076874942.6383
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 30/30
# 46/46 [==============================] - 0s 1ms/step - loss: 4136111300.0851
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss

# %% [markdown]
# Use the trained neural network on the test data.

# %%
test_x= np.array([[2003,	854, 1710,	2, 1, 3, 8, 2008], 
                  [1976,	0, 1262,	2, 0, 3, 6, 2007],
                  [2001,	866, 1786,	2, 1, 3, 6, 2008],
                  [1915,	756, 1717,	1, 0, 3, 7, 2006],
                  [2000,	1053, 2198,	2, 1, 4, 9, 2008]])
test_y = np.array([20850, 181500, 223500, 140000, 250000])
print('Model Estimates')
print(model.predict(test_x.reshape(5, 8), batch_size=5))
print('Actual Sales Prices')
print(test_y)
# Out:
# Model Estimates
# [[210424.05]
#  [167832.4 ]
#  [213929.12]
#  [205319.6 ]
#  [236951.12]]
# Actual Sales Prices
# [ 20850 181500 223500 140000 250000]
